# %% [markdown]
# <a href="https://colab.research.google.com/github/Reno20/EMPLOYEE_SALARY_PREDICTION/blob/main/EMPLOYEE_demo_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#loading library
import pandas as pd

# %%
data=pd.read_csv('adult.csv')

# %%
data
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 4       18          ?  103497  Some-college               10
# ...    ...        ...     ...           ...              ...
# 19235   26    Private  240842       HS-grad                9
# 19236   53    Private  103931  Some-college               10
# 19237   60    Private  232618     Bachelors               13
# 19238   49  Local-gov  288548       Masters               14
# 19239   40    Private  220609  Some-college               10
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
#null values
data.isna()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 19235  False      False   False      False            False           False
# 19236  False      False   False      False            False           False
# 19237  False      False   False      False            False           False
# 19238  False      False   False      False            False           False
# 19239  False      False   False      False            False           False
#
# ...

# %%
data.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       1
# hours-per-week     1
# native-country     1
# income             1
# dtype: int64

# %%
data.head(3)
# Out:
#    age  workclass  fnlwgt   education  educational-num      marital-status  \
# 0   25    Private  226802        11th                7       Never-married
# 1   38    Private   89814     HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951  Assoc-acdm               12  Married-civ-spouse
#
#           occupation relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black   Male             0           0.0
# 1    Farming-fishing      Husband  White   Male             0           0.0
# 2    Protective-serv      Husband  White   Male             0           0.0
#
#    hours-per-week native-country income
# 0            40.0  United-States  <=50K
# 1            50.0  United-States  <=50K
# 2            40.0  United-States   >50K

# %%
data.tail(7)
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 19233   22          ?   35448       HS-grad                9
# 19234   34    Private  225548     Bachelors               13
# 19235   26    Private  240842       HS-grad                9
# 19236   53    Private  103931  Some-college               10
# 19237   60    Private  232618     Bachelors               13
# 19238   49  Local-gov  288548       Masters               14
# 19239   40    Private  220609  Some-college               10
#
#            marital-status         occupation   relationship   race  gender  \
# 19233  Married-civ-spouse                  ?           Wife  White  Female
# 19234  Married-civ-spouse    Protective-serv        Husband  Black    Male
# 19235       Never-married  Machine-op-inspct      Unmarried  Black  Female
# 19236  Married-civ-spouse     Prof-specialty        Husband  White    Male
# 19237  Married-civ-spouse    Exec-managerial        Husband  White    Male
# ...

# %%
print(data.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       2395
# Exec-managerial      2380
# Craft-repair         2374
# Sales                2211
# Adm-clerical         2180
# Other-service        1933
# Machine-op-inspct    1205
# ?                    1156
# Transport-moving      906
# Handlers-cleaners     812
# Tech-support          608
# Farming-fishing       575
# Protective-serv       392
# Priv-house-serv       105
# Armed-Forces            8
# Name: count, dtype: int64

# %%
print(data.gender.value_counts())
# Out:
# gender
# Male      12857
# Female     6383
# Name: count, dtype: int64

# %%
print(data['marital-status'].value_counts())
# Out:
# marital-status
# Married-civ-spouse       8752
# Never-married            6402
# Divorced                 2595
# Widowed                   626
# Separated                 595
# Married-spouse-absent     253
# Married-AF-spouse          17
# Name: count, dtype: int64

# %%
print(data['education'].value_counts())
# Out:
# education
# HS-grad         6241
# Some-college    4234
# Bachelors       3167
# Masters         1102
# Assoc-voc        808
# 11th             767
# Assoc-acdm       626
# 10th             539
# 7th-8th          364
# Prof-school      307
# 9th              287
# 12th             252
# Doctorate        211
# 5th-6th          204
# 1st-4th           95
# Preschool         36
# Name: count, dtype: int64

# %%
print(data['workclass'].value_counts())
# Out:
# workclass
# Private             13244
# Self-emp-not-inc     1553
# Local-gov            1239
# ?                    1153
# State-gov             802
# Self-emp-inc          684
# Federal-gov           554
# Without-pay             8
# Never-worked            3
# Name: count, dtype: int64

# %%
data.occupation.replace({'?':'others'},inplace = True)
# Out:
# /tmp/ipython-input-16-1819146754.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.occupation.replace({'?':'others'},inplace = True)

# %%
print(data.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       2395
# Exec-managerial      2380
# Craft-repair         2374
# Sales                2211
# Adm-clerical         2180
# Other-service        1933
# Machine-op-inspct    1205
# others               1156
# Transport-moving      906
# Handlers-cleaners     812
# Tech-support          608
# Farming-fishing       575
# Protective-serv       392
# Priv-house-serv       105
# Armed-Forces            8
# Name: count, dtype: int64

# %%
data.workclass.replace({'?':'NotListed'},inplace = True)
# Out:
# /tmp/ipython-input-18-3406746076.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.workclass.replace({'?':'NotListed'},inplace = True)

# %%
print(data['workclass'].value_counts())
# Out:
# workclass
# Private             13244
# Self-emp-not-inc     1553
# Local-gov            1239
# NotListed            1153
# State-gov             802
# Self-emp-inc          684
# Federal-gov           554
# Without-pay             8
# Never-worked            3
# Name: count, dtype: int64

# %%
data= data[data['workclass']!='Without-pay']
data= data[data['workclass']!='Never-worked']

# %%
print(data['workclass'].value_counts())
# Out:
# workclass
# Private             13244
# Self-emp-not-inc     1553
# Local-gov            1239
# NotListed            1153
# State-gov             802
# Self-emp-inc          684
# Federal-gov           554
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (19229, 15)

# %%
data= data[data['education']!='5th-6th']
data= data[data['education']!='1st-4th']

data= data[data['education']!='Preschool']

# %%
print(data['education'].value_counts())
# Out:
# education
# HS-grad         6235
# Some-college    4234
# Bachelors       3167
# Masters         1102
# Assoc-voc        808
# 11th             765
# Assoc-acdm       625
# 10th             539
# 7th-8th          362
# Prof-school      307
# 9th              287
# 12th             252
# Doctorate        211
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (18894, 15)

# %%
#redundancy
data.drop(columns=['education'],inplace =True)

# %%
data
# Out:
#        age  workclass  fnlwgt  educational-num      marital-status  \
# 0       25    Private  226802                7       Never-married
# 1       38    Private   89814                9  Married-civ-spouse
# 2       28  Local-gov  336951               12  Married-civ-spouse
# 3       44    Private  160323               10  Married-civ-spouse
# 4       18  NotListed  103497               10       Never-married
# ...    ...        ...     ...              ...                 ...
# 19235   26    Private  240842                9       Never-married
# 19236   53    Private  103931               10  Married-civ-spouse
# 19237   60    Private  232618               13  Married-civ-spouse
# 19238   49  Local-gov  288548               14           Separated
# 19239   40    Private  220609               10            Divorced
#
#               occupation   relationship   race  gender  capital-gain  \
# 0      Machine-op-inspct      Own-child  Black    Male             0
# ...

# %%
import matplotlib.pyplot as plt

# %%
#outlier
plt.boxplot(data['age'])
plt.show()

# %%
data = data[(data['age']<=75)& (data['age']>17) ].copy()

# %%
plt.boxplot(data['age'])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['workclass']=encoder.fit_transform(data['workclass'])
# Out:
# /tmp/ipython-input-32-3410171805.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['workclass']=encoder.fit_transform(data['workclass'])

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['marital-status']=encoder.fit_transform(data['marital-status'])
data['workclass']=encoder.fit_transform(data['workclass'])
data['occupation']=encoder.fit_transform(data['occupation'])
data['relationship']=encoder.fit_transform(data['relationship'])
data['gender']=encoder.fit_transform(data['gender'])
data['race']=encoder.fit_transform(data['race'])
data['native-country']=encoder.fit_transform(data['native-country'])
data
# Out:
# /tmp/ipython-input-33-1041925315.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['marital-status']=encoder.fit_transform(data['marital-status'])
# /tmp/ipython-input-33-1041925315.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['workclass']=encoder.fit_transform(data['workclass'])
# /tmp/ipython-input-33-1041925315.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data.dropna(inplace=True)
x=data.drop(columns=['income'])
y=data['income']

# %%
x
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          3  226802                7               4           6
# 1       38          3   89814                9               2           4
# 2       28          1  336951               12               2          10
# 3       44          3  160323               10               2           6
# 4       18          2  103497               10               4          14
# ...    ...        ...     ...              ...             ...         ...
# 19234   34          3  225548               13               2          10
# 19235   26          3  240842                9               4           6
# 19236   53          3  103931               10               2           9
# 19237   60          3  232618               13               2           3
# 19238   49          1  288548               14               5           9
#
# ...

# %%
y
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 19234    <=50K
# 19235    <=50K
# 19236    <=50K
# 19237     >50K
# 19238    <=50K
# Name: income, Length: 18511, dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x=scaler.fit_transform(x)
x
# Out:
# array([[0.12280702, 0.5       , 0.14443012, ..., 0.        , 0.39795918,
#         0.95      ],
#        [0.35087719, 0.5       , 0.05167688, ..., 0.        , 0.5       ,
#         0.95      ],
#        [0.1754386 , 0.16666667, 0.21901093, ..., 0.        , 0.39795918,
#         0.95      ],
#        ...,
#        [0.61403509, 0.5       , 0.06123536, ..., 0.        , 0.39795918,
#         0.95      ],
#        [0.73684211, 0.5       , 0.14836808, ..., 0.        , 0.34693878,
#         0.95      ],
#        [0.54385965, 0.16666667, 0.18623773, ..., 0.        , 0.5       ,
#         0.95      ]])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=1,stratify=y)

# %%
xtrain
# Out:
# array([[0.43859649, 0.5       , 0.1940588 , ..., 0.        , 0.39795918,
#         0.95      ],
#        [0.28070175, 0.5       , 0.23595647, ..., 0.        , 0.39795918,
#         0.95      ],
#        [0.26315789, 0.5       , 0.16822375, ..., 0.        , 0.39795918,
#         0.325     ],
#        ...,
#        [0.33333333, 1.        , 0.11197989, ..., 0.        , 0.39795918,
#         0.95      ],
#        [0.50877193, 1.        , 0.15169056, ..., 0.        , 0.39795918,
#         0.95      ],
#        [0.26315789, 0.5       , 0.15092612, ..., 0.        , 0.55102041,
#         0.95      ]])

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(xtrain,ytrain)
predict=knn.predict(xtest)
predict #predicted value
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '<=50K', '>50K', '>50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,predict)
# Out:
# 0.8125843910342965

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(xtrain,ytrain)
predict1=lr.predict(xtest)
predict1 #predicted value
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '>50K', '>50K', '<=50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,predict1)
# Out:
# 0.8185255198487713

# %%
from sklearn.neural_network import MLPClassifier
mlp=MLPClassifier(solver='adam',hidden_layer_sizes=(5,1),random_state=2,max_iter=2000)
mlp.fit(xtrain,ytrain)
predict2=mlp.predict(xtest)
predict2 #predicted value
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '<=50K', '>50K', '<=50K'],
#       dtype='<U5')

# %%
from sklearn.metrics import accuracy_score
accuracy_score(ytest,predict2)
# Out:
# 0.8366189576019444
